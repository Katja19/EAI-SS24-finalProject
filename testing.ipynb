# %%
import pandas as pd
import sqlite3

# %%
housing_data =pd.read_csv("./melbourne.csv")
sensor = housing_data['Sensor_Name']
print(housing_data)
print(sensor)

#compare with https://www.visualcrossing.com/weather-history/Melbourne,Australia/metric
#compare australia day January 26th 2022(super warm and national holiday) to January 7th 2022 (extreme weather conditions)
# Out:
#               ID                      Date_Time  Year     Month  Mdate  \
# 0        2887628  November 01, 2019 05:00:00 PM  2019  November      1
# 1        2887629  November 01, 2019 05:00:00 PM  2019  November      1
# 2        2887630  November 01, 2019 05:00:00 PM  2019  November      1
# 3        2887631  November 01, 2019 05:00:00 PM  2019  November      1
# 4        2887632  November 01, 2019 05:00:00 PM  2019  November      1
# ...          ...                            ...   ...       ...    ...
# 4562225  4567697   October 31, 2022 07:00:00 PM  2022   October     31
# 4562226  4567698   October 31, 2022 08:00:00 PM  2022   October     31
# 4562227  4567699   October 31, 2022 09:00:00 PM  2022   October     31
# 4562228  4567700   October 31, 2022 10:00:00 PM  2022   October     31
# 4562229  4567701   October 31, 2022 11:00:00 PM  2022   October     31
#
#             Day  Time  Sensor_ID                   Sensor_Name  Hourly_Counts
# ...

# %%
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
sensor = housing_data['Sensor_Name'].value_counts()

print(sensor)
# Out:
# Sensor_Name
# Bourke Street Mall (South)                  118123
# Southern Cross Station                      118097
# Flinders Street Station Underpass           117929
# Victoria Point                              117801
# Waterfront City                             116844
#                                              ...
# Bourke St - Spencer St (South)                3648
# Errol St (West)                               2952
# Flinders La - Swanston St (West) Temp         1379
# Flinders la - Swanston St (West) Temp          912
# Harbour Esplanade (West) - Pedestrian Pa       744
# Name: count, Length: 94, dtype: int64

# %%
housing_data=housing_data.rename(columns={"Sensor_Name":"location_name"})
#housing_data=housing_data.drop(columns=['Mdate'])

print(housing_data)
# Out:
#               ID                      Date_Time  Year     Month  Mdate  \
# 0        2887628  November 01, 2019 05:00:00 PM  2019  November      1
# 1        2887629  November 01, 2019 05:00:00 PM  2019  November      1
# 2        2887630  November 01, 2019 05:00:00 PM  2019  November      1
# 3        2887631  November 01, 2019 05:00:00 PM  2019  November      1
# 4        2887632  November 01, 2019 05:00:00 PM  2019  November      1
# ...          ...                            ...   ...       ...    ...
# 4562225  4567697   October 31, 2022 07:00:00 PM  2022   October     31
# 4562226  4567698   October 31, 2022 08:00:00 PM  2022   October     31
# 4562227  4567699   October 31, 2022 09:00:00 PM  2022   October     31
# 4562228  4567700   October 31, 2022 10:00:00 PM  2022   October     31
# 4562229  4567701   October 31, 2022 11:00:00 PM  2022   October     31
#
#             Day  Time  Sensor_ID                 location_name  Hourly_Counts
# ...

# %%
weather_data=pd.read_csv('wuerzburg.csv')
weather_data.head()
# Out:
#        name             datetime  temp  feelslike  dew  humidity  precip  \
# 0  würzburg  2024-01-01T00:00:00   4.8        2.3  2.9     87.50     0.0
# 1  würzburg  2024-01-01T01:00:00   4.9        1.8  1.9     80.73     0.0
# 2  würzburg  2024-01-01T02:00:00   6.2        1.9  2.1     75.01     0.0
# 3  würzburg  2024-01-01T03:00:00   6.2        1.9  2.2     75.55     0.0
# 4  würzburg  2024-01-01T04:00:00   5.7        1.5  2.4     79.25     0.0
#
#    precipprob preciptype  snow  ...  sealevelpressure  cloudcover  visibility  \
# 0           0        NaN   0.0  ...            1008.0        71.8         NaN
# 1           0        NaN   0.0  ...            1009.0        72.5        23.0
# 2           0        NaN   0.0  ...            1008.4        76.7        45.0
# 3           0        NaN   0.0  ...            1008.9        79.7        44.0
# 4           0        NaN   0.0  ...            1008.7        95.8        36.0
#
# ...

# %%
connection = sqlite3.connect('data.db')
data = pd.read_sql('SELECT * FROM data ORDER BY timestamp', connection)
data
# Out:
#          location_name  pedestrians_count  temperature  \
# 0      Schönbornstraße               1346          5.0
# 1        Spiegelstraße                388          5.0
# 2         Kaiserstraße               1197          5.0
# 3      Schönbornstraße                772          5.0
# 4        Spiegelstraße                161          5.0
# ...                ...                ...          ...
# 11111    Spiegelstraße                  6          9.0
# 11112     Kaiserstraße                 12          9.0
# 11113  Schönbornstraße                  9          8.0
# 11114    Spiegelstraße                  4          8.0
# 11115     Kaiserstraße                 10          8.0
#
#                        timestamp    weather_condition  unverified  location_id
# 0      2024-01-01T00:00:00+01:00  partly-cloudy-night         0.0        135.0
# 1      2024-01-01T00:00:00+01:00  partly-cloudy-night         0.0        470.0
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,shuffle=False)
